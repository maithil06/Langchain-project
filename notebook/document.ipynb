# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document
# Out:
# d:\Git uploads\LangchainLearning\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
doc = Document(
    page_content = "This is the main text content of the document I am using to create RAG",
    metadata = {
        "source" : "example.txt",
        "author" : "Maithil Tandel",
        "pages" : 1,
        "date_created" : "2026-01-06"
    })
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'Maithil Tandel', 'pages': 1, 'date_created': '2026-01-06'}, page_content='This is the main text content of the document I am using to create RAG')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_into.txt" : """Introduction to Large Language models

    Python is a high-level, interpreted programming langugage know for its readibility and versatility. It was created by 
    Guido van Rossum and first released in 1991. Python's desgin philosophy emphasizes code readability and a synatx that
    allows programmers to express concepts in fewer lines of code compared to other programming languages.


    Key features of Python:
- Readability and simplicity
- Interpreted and cross-platform
- Dynamic typing with strong runtime flexibility
- Rich built-in data structures (list, dict, set, tuple)
- Extensive standard library ("batteries included")
- Large ecosystem of third-party packages (PyPI)
- Supports procedural, object-oriented, and functional programming
- Automatic memory management (garbage collection)
- Excellent tooling and community support
- Easy interoperability with C/C++ and other languages """
}

# %%
for file_path, context in sample_texts.items():
    with open(file_path, "w", encoding = "utf-8") as f:
        f.write(context)

# %%
from langchain_community.document_loaders import TextLoader

loader =  TextLoader("D:\\Git uploads\\LangchainLearning\\data\\text_files\\python_into.txt", encoding = 'utf-8')
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': 'D:\\Git uploads\\LangchainLearning\\data\\text_files\\python_into.txt'}, page_content='Introduction to Large Language models\n\n    Python is a high-level, interpreted programming langugage know for its readibility and versatility. It was created by \n    Guido van Rossum and first released in 1991. Python\'s desgin philosophy emphasizes code readability and a synatx that\n    allows programmers to express concepts in fewer lines of code compared to other programming languages.\n\n\n    Key features of Python:\n- Readability and simplicity\n- Interpreted and cross-platform\n- Dynamic typing with strong runtime flexibility\n- Rich built-in data structures (list, dict, set, tuple)\n- Extensive standard library ("batteries included")\n- Large ecosystem of third-party packages (PyPI)\n- Supports procedural, object-oriented, and functional programming\n- Automatic memory management (garbage collection)\n- Excellent tooling and community support\n- Easy inter
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "D:\\Git uploads\\LangchainLearning\\data\\text_files",
    glob = "**/*.txt",
    loader_cls = TextLoader,
    loader_kwargs = {"encoding" : "utf-8"},
    show_progress = True
)

documnets = dir_loader.load()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 308.50it/s]

# %%
# Out:
# [Document(metadata={'source': 'D:\\Git uploads\\LangchainLearning\\data\\text_files\\python_into.txt'}, page_content='Introduction to Large Language models\n\n    Python is a high-level, interpreted programming langugage know for its readibility and versatility. It was created by \n    Guido van Rossum and first released in 1991. Python\'s desgin philosophy emphasizes code readability and a synatx that\n    allows programmers to express concepts in fewer lines of code compared to other programming languages.\n\n\n    Key features of Python:\n- Readability and simplicity\n- Interpreted and cross-platform\n- Dynamic typing with strong runtime flexibility\n- Rich built-in data structures (list, dict, set, tuple)\n- Extensive standard library ("batteries included")\n- Large ecosystem of third-party packages (PyPI)\n- Supports procedural, object-oriented, and functional programming\n- Automatic memory management (garbage collection)\n- Excellent tooling and community support\n- Easy inter
# ...
